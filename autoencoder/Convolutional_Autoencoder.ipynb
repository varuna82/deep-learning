# %% [markdown]
# # Convolutional Autoencoder
#
# Sticking with the MNIST dataset, let's improve our autoencoder's performance using convolutional layers. Again, loading modules and the data.

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# /home/aind2/anaconda3/envs/aind2/lib/python3.6/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
img = mnist.train.images[2]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# ## Network Architecture
#
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer will be followed by a max-pooling layer to reduce the dimensions of the layers. The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide reconstructed image. For example, the representation could be a 4x4x8 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the narrow decoder input layer. A schematic of the network is shown below.
#
# <img src='assets/convolutional_autoencoder.png' width=500px>
#
# Here our final encoder layer has size 4x4x8 = 128. The original images have size 28x28 = 784, so the encoded vector is roughly 16% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, but remember our goal here is to find a small representation of the input data.
#
# ### What's going on with the decoder
#
# Okay, so the decoder has these "Upsample" layers that you might not have seen before. First off, I'll discuss a bit what these layers *aren't*. Usually, you'll see **transposed convolution** layers used to increase the width and height of the layers. They work almost exactly the same as convolutional layers, but in reverse. A stride in the input layer results in a larger stride in the transposed convolution layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a transposed convolution layer. The TensorFlow API provides us with an easy way to create the layers, [`tf.nn.conv2d_transpose`](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d_transpose).
#
# However, transposed convolution layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer. In TensorFlow, this is easily done with [`tf.image.resize_images`](https://www.tensorflow.org/versions/r1.1/api_docs/python/tf/image/resize_images), followed by a convolution. Be sure to read the Distill article to get a better understanding of deconvolutional layers and why we're using upsampling.
#
# > **Exercise:** Build the network shown above. Remember that a convolutional layer with strides of 1 and 'same' padding won't reduce the height and width. That is, if the input is 28x28 and the convolution layer has stride = 1 and 'same' padding, the convolutional layer will also be 28x28. The max-pool layers are used the reduce the width and height. A stride of 2 will reduce the size by a factor of 2. Odena *et al* claim that nearest neighbor interpolation works best for the upsampling, so make sure to include that as a parameter in `tf.image.resize_images` or use [`tf.image.resize_nearest_neighbor`]( `https://www.tensorflow.org/api_docs/python/tf/image/resize_nearest_neighbor). For convolutional layers, use [`tf.layers.conv2d`](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d). For example, you would write `conv1 = tf.layers.conv2d(inputs, 32, (5,5), padding='same', activation=tf.nn.relu)` for a layer with a depth of 32, a 5x5 kernel, stride of (1,1), padding is 'same', and a ReLU activation. Similarly, for the max-pool layers, use [`tf.layers.max_pooling2d`](https://www.tensorflow.org/api_docs/python/tf/layers/max_pooling2d).

# %%
learning_rate = 0.001

# Input and target placeholders
inputs_ = tf.placeholder(tf.float32, shape=(None, 28, 28, 1))
targets_ = tf.placeholder(tf.float32, shape=(None, 28, 28, 1))

### Encoder
conv1 = tf.layers.conv2d(inputs_, 16, (3, 3), padding='same', activation=tf.nn.relu)
# Now 28x28x16
maxpool1 = tf.layers.max_pooling2d(conv1, (2, 2), (2, 2), padding='same')
# Now 14x14x16
conv2 = tf.layers.conv2d(maxpool1, 8, (3, 3), padding='same', activation=tf.nn.relu)
# Now 14x14x8
maxpool2 = tf.layers.max_pooling2d(conv2, (2, 2), (2, 2), padding='same')
# Now 7x7x8
conv3 = tf.layers.conv2d(maxpool2, 8, (3, 3), padding='same', activation=tf.nn.relu)
# Now 7x7x8
encoded =tf.layers.max_pooling2d(conv2, (2, 2), (2, 2), padding='same')
# Now 4x4x8

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, (7, 7))

# Now 7x7x8
conv4 = tf.layers.conv2d(upsample1, 8, (3, 3), padding='same')
# Now 7x7x8
upsample2 = tf.image.resize_nearest_neighbor(conv4, (14, 14))
# Now 14x14x8
conv5 = tf.layers.conv2d(upsample2, 8, (3, 3), padding='same', activation=tf.nn.relu)
# Now 14x14x8
upsample3 = tf.image.resize_nearest_neighbor(conv5, (28, 28))
# Now 28x28x8
conv6 = tf.layers.conv2d(upsample3, 16, (3, 3), padding='same', activation=tf.nn.relu)
# Now 28x28x16

logits = tf.layers.conv2d(conv6, 1, (3, 3), padding='same', activation=None)
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=targets_)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Training
#
# As before, here we'll train the network. Instead of flattening the images though, we can pass them in as 28x28x1 arrays.

# %%
sess = tf.Session()

# %%
epochs = 2
num_examples = mnist.train.num_examples

batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    
    for ii in range(num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        imgs = batch[0].reshape((-1, 28, 28, 1))
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/2... Training loss: 0.6855
# Epoch: 1/2... Training loss: 0.6801
# Epoch: 1/2... Training loss: 0.6738
# Epoch: 1/2... Training loss: 0.6660
# Epoch: 1/2... Training loss: 0.6571
# Epoch: 1/2... Training loss: 0.6467
# Epoch: 1/2... Training loss: 0.6356
# Epoch: 1/2... Training loss: 0.6234
# Epoch: 1/2... Training loss: 0.6086
# Epoch: 1/2... Training loss: 0.5961
# Epoch: 1/2... Training loss: 0.5781
# Epoch: 1/2... Training loss: 0.5659
# Epoch: 1/2... Training loss: 0.1491
# Epoch: 1/2... Training loss: 0.1480
# Epoch: 1/2... Training loss: 0.1493
# Epoch: 1/2... Training loss: 0.1456
# Epoch: 1/2... Training loss: 0.1464
# Epoch: 1/2... Training loss: 0.1458
# Epoch: 1/2... Training loss: 0.1467
# Epoch: 1/2... Training loss: 0.1415
# Epoch: 1/2... Training loss: 0.1407
# Epoch: 1/2... Training loss: 0.1415
# Epoch: 1/2... Training loss: 0.1390
# Epoch: 1/2... Training loss: 0.1403
# Epoch: 1/2... Training loss: 0.1374
# Epoch: 1/2... Training loss: 0.1390
# Epoch: 1/2... Training loss: 0.1388
# Epoch: 1/2... Training loss: 0.1354
# Epoch: 1/2... Training loss: 0.1335
# Epoch: 1/2... Training loss: 0.1399
# Epoch: 1/2... Training loss: 0.1337
# Epoch: 1/2... Training loss: 0.1359
# Epoch: 1/2... Training loss: 0.1350
# Epoch: 1/2... Training loss: 0.1365
# Epoch: 1/2... Training loss: 0.1277
# Epoch: 1/2... Training loss: 0.1335
# Epoch: 1/2... Training loss: 0.1331
# Epoch: 1/2... Training loss: 0.1317
# Epoch: 1/2... Training loss: 0.1313
# Epoch: 1/2... Training loss: 0.1268
# Epoch: 1/2... Training loss: 0.1311
# Epoch: 1/2... Training loss: 0.1284
# Epoch: 1/2... Training loss: 0.1304
# Epoch: 1/2... Training loss: 0.1268
# Epoch: 1/2... Training loss: 0.1268
# Epoch: 1/2... Training loss: 0.1241
# Epoch: 1/2... Training loss: 0.1262
# Epoch: 1/2... Training loss: 0.1240
# Epoch: 1/2... Training loss: 0.1254
# Epoch: 1/2... Training loss: 0.1262
# Epoch: 1/2... Training loss: 0.1256
# Epoch: 1/2... Training loss: 0.1242
# Epoch: 1/2... Training loss: 0.1240
# Epoch: 1/2... Training loss: 0.1199
# Epoch: 1/2... Training loss: 0.1184
# Epoch: 1/2... Training loss: 0.1219
# Epoch: 1/2... Training loss: 0.1177
# Epoch: 1/2... Training loss: 0.1140
# Epoch: 1/2... Training loss: 0.1217
# Epoch: 1/2... Training loss: 0.1191
# Epoch: 1/2... Training loss: 0.1139
# Epoch: 1/2... Training loss: 0.1124
# Epoch: 1/2... Training loss: 0.1117
# Epoch: 1/2... Training loss: 0.1179
# Epoch: 1/2... Training loss: 0.1140
# Epoch: 1/2... Training loss: 0.1174
# Epoch: 1/2... Training loss: 0.1134
# Epoch: 1/2... Training loss: 0.1118
# Epoch: 1/2... Training loss: 0.1174
# Epoch: 1/2... Training loss: 0.1151
# Epoch: 1/2... Training loss: 0.1172
# Epoch: 1/2... Training loss: 0.1135
# Epoch: 1/2... Training loss: 0.1134
# Epoch: 1/2... Training loss: 0.1123
# Epoch: 1/2... Training loss: 0.1136
# Epoch: 1/2... Training loss: 0.1068
# Epoch: 1/2... Training loss: 0.1157
# Epoch: 1/2... Training loss: 0.1099
# Epoch: 1/2... Training loss: 0.1083
# Epoch: 1/2... Training loss: 0.1110
# Epoch: 1/2... Training loss: 0.1137
# Epoch: 1/2... Training loss: 0.1084
# Epoch: 1/2... Training loss: 0.1047
# Epoch: 1/2... Training loss: 0.1112
# Epoch: 1/2... Training loss: 0.1087
# Epoch: 1/2... Training loss: 0.1098
# Epoch: 1/2... Training loss: 0.1066
# Epoch: 1/2... Training loss: 0.1103
# Epoch: 1/2... Training loss: 0.1081
# Epoch: 1/2... Training loss: 0.1065
# Epoch: 1/2... Training loss: 0.1093
# Epoch: 1/2... Training loss: 0.1055
# Epoch: 1/2... Training loss: 0.1078
# Epoch: 1/2... Training loss: 0.1087
# Epoch: 1/2... Training loss: 0.1068
# Epoch: 1/2... Training loss: 0.1077
# Epoch: 1/2... Training loss: 0.1079
# Epoch: 1/2... Training loss: 0.1061
# Epoch: 1/2... Training loss: 0.1081
# Epoch: 1/2... Training loss: 0.1024
# Epoch: 1/2... Training loss: 0.1090
# Epoch: 1/2... Training loss: 0.1056
# Epoch: 1/2... Training loss: 0.1030
# Epoch: 1/2... Training loss: 0.1070
# Epoch: 1/2... Training loss: 0.1020
# Epoch: 1/2... Training loss: 0.1058
# Epoch: 1/2... Training loss: 0.1073
# Epoch: 1/2... Training loss: 0.1045
# Epoch: 1/2... Training loss: 0.1055
# Epoch: 1/2... Training loss: 0.1048
# Epoch: 1/2... Training loss: 0.1014
# Epoch: 1/2... Training loss: 0.1062
# Epoch: 1/2... Training loss: 0.1056
# Epoch: 1/2... Training loss: 0.1030
# Epoch: 1/2... Training loss: 0.1022
# Epoch: 1/2... Training loss: 0.1016
# Epoch: 1/2... Training loss: 0.0998
# Epoch: 1/2... Training loss: 0.1006
# Epoch: 1/2... Training loss: 0.1049
# Epoch: 1/2... Training loss: 0.1017
# Epoch: 1/2... Training loss: 0.1005
# Epoch: 1/2... Training loss: 0.1034
# Epoch: 1/2... Training loss: 0.1061
# Epoch: 1/2... Training loss: 0.1025
# Epoch: 1/2... Training loss: 0.1015
# Epoch: 1/2... Training loss: 0.1013
# Epoch: 1/2... Training loss: 0.1005
# Epoch: 1/2... Training loss: 0.0958
# Epoch: 1/2... Training loss: 0.1012
# Epoch: 1/2... Training loss: 0.1029
# Epoch: 1/2... Training loss: 0.1019
# Epoch: 1/2... Training loss: 0.1024
# Epoch: 1/2... Training loss: 0.1006
# Epoch: 1/2... Training loss: 0.1035
# Epoch: 1/2... Training loss: 0.1020
# Epoch: 1/2... Training loss: 0.0995
# Epoch: 1/2... Training loss: 0.1002
# Epoch: 1/2... Training loss: 0.1023
# Epoch: 1/2... Training loss: 0.0990
# Epoch: 1/2... Training loss: 0.1001
# Epoch: 1/2... Training loss: 0.0974
# Epoch: 1/2... Training loss: 0.0986
# Epoch: 1/2... Training loss: 0.1025
# Epoch: 1/2... Training loss: 0.0974
# Epoch: 1/2... Training loss: 0.1001
# Epoch: 1/2... Training loss: 0.0951
# Epoch: 1/2... Training loss: 0.0996
# Epoch: 1/2... Training loss: 0.0982
# Epoch: 2/2... Training loss: 0.0894
# Epoch: 2/2... Training loss: 0.0916
# Epoch: 2/2... Training loss: 0.0940
# Epoch: 2/2... Training loss: 0.0923
# Epoch: 2/2... Training loss: 0.0863
# Epoch: 2/2... Training loss: 0.0921
# Epoch: 2/2... Training loss: 0.0893
# Epoch: 2/2... Training loss: 0.0904
# Epoch: 2/2... Training loss: 0.0889
# Epoch: 2/2... Training loss: 0.0894
# Epoch: 2/2... Training loss: 0.0871
# Epoch: 2/2... Training loss: 0.0922
# Epoch: 2/2... Training loss: 0.0922
# Epoch: 2/2... Training loss: 0.0893
# Epoch: 2/2... Training loss: 0.0885
# Epoch: 2/2... Training loss: 0.0893
# Epoch: 2/2... Training loss: 0.0876
# Epoch: 2/2... Training loss: 0.0925
# Epoch: 2/2... Training loss: 0.0910
# Epoch: 2/2... Training loss: 0.0880
# Epoch: 2/2... Training loss: 0.0894
# Epoch: 2/2... Training loss: 0.0906
# Epoch: 2/2... Training loss: 0.0902
# Epoch: 2/2... Training loss: 0.0904
# Epoch: 2/2... Training loss: 0.0873
# Epoch: 2/2... Training loss: 0.0894
# Epoch: 2/2... Training loss: 0.0884
# Epoch: 2/2... Training loss: 0.0891
# Epoch: 2/2... Training loss: 0.0904
# Epoch: 2/2... Training loss: 0.0892
# Epoch: 2/2... Training loss: 0.0860
# Epoch: 2/2... Training loss: 0.0906
# Epoch: 2/2... Training loss: 0.0878
# Epoch: 2/2... Training loss: 0.0906
# Epoch: 2/2... Training loss: 0.0897
# Epoch: 2/2... Training loss: 0.0916
# Epoch: 2/2... Training loss: 0.0893
# Epoch: 2/2... Training loss: 0.0882
# Epoch: 2/2... Training loss: 0.0894
# Epoch: 2/2... Training loss: 0.0899
# Epoch: 2/2... Training loss: 0.0875
# Epoch: 2/2... Training loss: 0.0879
# Epoch: 2/2... Training loss: 0.0903
# Epoch: 2/2... Training loss: 0.0857
# Epoch: 2/2... Training loss: 0.0866
# Epoch: 2/2... Training loss: 0.0882
# Epoch: 2/2... Training loss: 0.0893
# Epoch: 2/2... Training loss: 0.0869
# Epoch: 2/2... Training loss: 0.0858
# Epoch: 2/2... Training loss: 0.0863
# Epoch: 2/2... Training loss: 0.0865
# Epoch: 2/2... Training loss: 0.0900
# Epoch: 2/2... Training loss: 0.0890
# Epoch: 2/2... Training loss: 0.0889
# Epoch: 2/2... Training loss: 0.0881
# Epoch: 2/2... Training loss: 0.0887
# Epoch: 2/2... Training loss: 0.0875
# Epoch: 2/2... Training loss: 0.0873
# Epoch: 2/2... Training loss: 0.0864
# Epoch: 2/2... Training loss: 0.0857
# Epoch: 2/2... Training loss: 0.0903
# Epoch: 2/2... Training loss: 0.0844
# Epoch: 2/2... Training loss: 0.0869
# Epoch: 2/2... Training loss: 0.0872
# Epoch: 2/2... Training loss: 0.0882
# Epoch: 2/2... Training loss: 0.0895
# Epoch: 2/2... Training loss: 0.0886
# Epoch: 2/2... Training loss: 0.0858
# Epoch: 2/2... Training loss: 0.0849
# Epoch: 2/2... Training loss: 0.0833
# Epoch: 2/2... Training loss: 0.0844
# Epoch: 2/2... Training loss: 0.0832
# Epoch: 2/2... Training loss: 0.0816
# Epoch: 2/2... Training loss: 0.0850
# Epoch: 2/2... Training loss: 0.0846
# Epoch: 2/2... Training loss: 0.0827
# Epoch: 2/2... Training loss: 0.0823
# Epoch: 2/2... Training loss: 0.0862
# Epoch: 2/2... Training loss: 0.0813
# Epoch: 2/2... Training loss: 0.0824
# Epoch: 2/2... Training loss: 0.0838
# Epoch: 2/2... Training loss: 0.0828
# Epoch: 2/2... Training loss: 0.0847
# Epoch: 2/2... Training loss: 0.0870
# Epoch: 2/2... Training loss: 0.0836
# Epoch: 2/2... Training loss: 0.0847
# Epoch: 2/2... Training loss: 0.0845
# Epoch: 2/2... Training loss: 0.0831
# Epoch: 2/2... Training loss: 0.0847
# Epoch: 2/2... Training loss: 0.0849
# Epoch: 2/2... Training loss: 0.0829
# Epoch: 2/2... Training loss: 0.0832
# Epoch: 2/2... Training loss: 0.0835
# Epoch: 2/2... Training loss: 0.0820
# Epoch: 2/2... Training loss: 0.0830
# Epoch: 2/2... Training loss: 0.0818
# Epoch: 2/2... Training loss: 0.0843
# Epoch: 2/2... Training loss: 0.0823
# Epoch: 2/2... Training loss: 0.0856
# Epoch: 2/2... Training loss: 0.0832
# Epoch: 2/2... Training loss: 0.0834
# Epoch: 2/2... Training loss: 0.0834
# Epoch: 2/2... Training loss: 0.0812
# Epoch: 2/2... Training loss: 0.0840
# Epoch: 2/2... Training loss: 0.0825
# Epoch: 2/2... Training loss: 0.0840
# Epoch: 2/2... Training loss: 0.0830
# Epoch: 2/2... Training loss: 0.0846
# Epoch: 2/2... Training loss: 0.0832
# Epoch: 2/2... Training loss: 0.0838
# Epoch: 2/2... Training loss: 0.0828
# Epoch: 2/2... Training loss: 0.0829
# Epoch: 2/2... Training loss: 0.0816

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed = sess.run(decoded, feed_dict={inputs_: in_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)


fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Denoising
#
# As I've mentioned before, autoencoders like the ones you've built so far aren't too useful in practive. However, they can be used to denoise images quite successfully just by training the network on noisy images. We can create the noisy images ourselves by adding Gaussian noise to the training images, then clipping the values to be between 0 and 1. We'll use noisy images as input and the original, clean images as targets. Here's an example of the noisy images I generated and the denoised images.
#
# ![Denoising autoencoder](assets/denoising.png)
#
#
# Since this is a harder problem for the network, we'll want to use deeper convolutional layers here, more feature maps. I suggest something like 32-32-16 for the depths of the convolutional layers in the encoder, and the same depths going backward through the decoder. Otherwise the architecture is the same as before.
#
# > **Exercise:** Build the network for the denoising autoencoder. It's the same as before, but with deeper layers. I suggest 32-32-16 for the depths, but you can play with these numbers, or add more layers.

# %%
learning_rate = 0.001
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 64, (3, 3), padding='same', activation=tf.nn.relu)
# Now 28x28x64
maxpool1 = tf.layers.max_pooling2d(conv1, (2, 2), (2, 2), padding='same')
# Now 14x14x32
conv2 = tf.layers.conv2d(maxpool1, 32, (3, 3), padding='same', activation=tf.nn.relu)
# Now 14x14x32
maxpool2 = tf.layers.max_pooling2d(conv2, (2, 2), (2, 2), padding='same')
# Now 7x7x32
conv3 = tf.layers.conv2d(maxpool2, 16, (3, 3), padding='same', activation=tf.nn.relu)
# Now 7x7x16
encoded = tf.layers.max_pooling2d(conv3, (2, 2), (2, 2), padding='same')
# Now 4x4x16

### Decoder
upsample1 = tf.image.resize_nearest_neighbor(encoded, (7, 7))
# Now 7x7x16
conv4 = tf.layers.conv2d(upsample1, 16, (3, 3), padding='same', activation=tf.nn.relu)
# Now 7x7x16
upsample2 = tf.image.resize_nearest_neighbor(conv4, (14, 14))
# Now 14x14x16
conv5 = tf.layers.conv2d(upsample2, 32, (3, 3), padding='same', activation=tf.nn.relu)
# Now 14x14x32
upsample3 = tf.image.resize_nearest_neighbor(conv5, (28, 28))
# Now 28x28x32
conv6 = tf.layers.conv2d(upsample3, 64, (3, 3), padding='same', activation=tf.nn.relu)
# Now 28x28x64

logits = tf.layers.conv2d(conv6, 1, (3, 3), padding='same', activation=None)
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
sess = tf.Session()

# %%
epochs = 2
num_examples = mnist.train.num_examples
batch_size = 2000
# Set's how much noise we're adding to the MNIST images
noise_factor = 0.5
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        # Get images from the batch
        imgs = batch[0].reshape((-1, 28, 28, 1))
        
        # Add random noise to the input images
        noisy_imgs = imgs + noise_factor * np.random.randn(*imgs.shape)
        # Clip the images to be between 0 and 1
        noisy_imgs = np.clip(noisy_imgs, 0., 1.)
        
        # Noisy images as inputs, original images as targets
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: noisy_imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/2... Training loss: 0.6879
# Epoch: 1/2... Training loss: 0.6649
# Epoch: 1/2... Training loss: 0.6279
# Epoch: 1/2... Training loss: 0.5712
# Epoch: 1/2... Training loss: 0.5077
# Epoch: 1/2... Training loss: 0.4849
# Epoch: 1/2... Training loss: 0.5079
# Epoch: 1/2... Training loss: 0.5052
# Epoch: 1/2... Training loss: 0.4691
# Epoch: 1/2... Training loss: 0.4425
# Epoch: 1/2... Training loss: 0.4318
# Epoch: 1/2... Training loss: 0.4220
# Epoch: 1/2... Training loss: 0.4103
# Epoch: 1/2... Training loss: 0.3944
# Epoch: 1/2... Training loss: 0.3765
# Epoch: 1/2... Training loss: 0.3622
# Epoch: 1/2... Training loss: 0.3465
# Epoch: 1/2... Training loss: 0.3347
# Epoch: 1/2... Training loss: 0.3187
# Epoch: 1/2... Training loss: 0.3086
# Epoch: 1/2... Training loss: 0.2971
# Epoch: 1/2... Training loss: 0.2891
# Epoch: 1/2... Training loss: 0.2856
# Epoch: 1/2... Training loss: 0.2848
# Epoch: 1/2... Training loss: 0.2785
# Epoch: 1/2... Training loss: 0.2757
# Epoch: 1/2... Training loss: 0.2731
# Epoch: 1/2... Training loss: 0.2709
# Epoch: 1/2... Training loss: 0.2704
# Epoch: 1/2... Training loss: 0.2723
# Epoch: 2/2... Training loss: 0.2713
# Epoch: 2/2... Training loss: 0.2723
# Epoch: 2/2... Training loss: 0.2703
# Epoch: 2/2... Training loss: 0.2678
# Epoch: 2/2... Training loss: 0.2684
# Epoch: 2/2... Training loss: 0.2651
# Epoch: 2/2... Training loss: 0.2672
# Epoch: 2/2... Training loss: 0.2637
# Epoch: 2/2... Training loss: 0.2638
# Epoch: 2/2... Training loss: 0.2628
# Epoch: 2/2... Training loss: 0.2614
# Epoch: 2/2... Training loss: 0.2605
# Epoch: 2/2... Training loss: 0.2607
# Epoch: 2/2... Training loss: 0.2583
# Epoch: 2/2... Training loss: 0.2542
# Epoch: 2/2... Training loss: 0.2550
# Epoch: 2/2... Training loss: 0.2532
# Epoch: 2/2... Training loss: 0.2524
# Epoch: 2/2... Training loss: 0.2486
# Epoch: 2/2... Training loss: 0.2478
# Epoch: 2/2... Training loss: 0.2479
# Epoch: 2/2... Training loss: 0.2464
# Epoch: 2/2... Training loss: 0.2472
# Epoch: 2/2... Training loss: 0.2437
# Epoch: 2/2... Training loss: 0.2407
# Epoch: 2/2... Training loss: 0.2461
# Epoch: 2/2... Training loss: 0.2407
# Epoch: 2/2... Training loss: 0.2422
# Epoch: 2/2... Training loss: 0.2352
# Epoch: 2/2... Training loss: 0.2419

# %% [markdown]
# ## Checking out the performance
#
# Here I'm adding noise to the test images and passing them through the autoencoder. It does a suprisingly great job of removing the noise, even though it's sometimes difficult to tell what the original number is.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
noisy_imgs = in_imgs + noise_factor * np.random.randn(*in_imgs.shape)
noisy_imgs = np.clip(noisy_imgs, 0., 1.)

reconstructed = sess.run(decoded, feed_dict={inputs_: noisy_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([noisy_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)
